# %%
import pandas as pd
import numpy as np

# %%
data={"Car_ID":list(range(1001,1051)),
"Brand":["Toyota", "Honda", "Hyundai", "Maruti", "Tata",
        "Toyota", "Honda", "Hyundai", "Ford", "Kia",
        "Tata", "Toyota", "Honda", "Maruti", "Hyundai",
        "Kia", "Ford", "Toyota", "Tata", "Honda",
        "Hyundai", "Maruti", "Kia", "Toyota", "Ford",
        "Honda", "Tata", "Hyundai", "Toyota", "Maruti",
        "Kia", "Honda", "Ford", "Tata", "Toyota",
        "Hyundai", "Maruti", "Honda", "Kia", "Toyota",
        "Ford", "Tata", "Hyundai", "Honda", "Maruti",
        "Toyota", "Kia", "Ford", "Tata", "Honda"],
"Model":["Camry", "Civic", "Creta", "Swift", "Nexon",
        "Corolla", "City", "i20", "EcoSport", "Seltos",
        "Harrier", "Fortuner", "Amaze", "Baleno", "Venue",
        "Sonet", "Endeavour", "Innova", "Nexon", "City",
        "Verna", "Swift", "Carens", "Corolla", "Aspire",
        "Civic", "Punch", "Creta", "Camry", "Baleno",
        "Seltos", "Amaze", "EcoSport", "Harrier", "Fortuner",
        "i20", "Swift", "City", "Sonet", "Innova",
        "Endeavour", "Nexon", "Verna", "Civic", "Baleno",
        "Camry", "Carens", "Aspire", "Punch", "Amaze"],
"Year":[2020, 2019, 2021, 2018, 2022,
        2020, 2019, 2021, 2018, 2022,
        2020, 2021, 2019, 2022, 2020,
        2021, 2018, 2022, 2020, 2019,
        2021, 2018, 2022, 2020, 2019,
        2021, 2022, 2020, 2019, 2021,
        2022, 2018, 2020, 2021, 2019,
        2022, 2020, 2018, 2021, 2022,
        2019, 2020, 2021, 2018, 2022,
        2020, 2019, 2021, 2022, 2018],
"Price":[25000, 22000, 24000, 12000, 18000,
        27000, 21000, 16000, 15000, 23000,
        28000, 42000, 17000, 14000, 19000,
        21000, 35000, 30000, 20000, 19000,
        18000, 11000, 25000, 26000, 13000,
        23000, 10000, 22000, 29000, 15000,
        24000, 16000, 14000, 27000, 40000,
        17000, 12500, 20000, 21500, 31000,
        33000, 19000, 17500, 22500, 13500,
        30000, 24500, 14500, 15500, 18500],
"Mileage":[45000, 52000, 30000, 60000, 25000,
        40000, 48000, 35000, 70000, 28000,
        32000, 45000, 50000, 22000, 38000,
        29000, 65000, 41000, 33000, 55000,
        27000, 62000, 24000, 36000, 68000,
        42000, 31000, 39000, 28000, 46000,
        26000, 53000, 72000, 34000, 44000,
        37000, 58000, 49000, 23000, 35000,
        61000, 30000, 32000, 47000, 54000,
        29000, 25000, 66000, 43000, 51000],
"Fuel_Type":["Petrol", "Diesel", "Petrol", "Petrol", "Diesel",
        "Petrol", "Diesel", "Petrol", "Diesel", "Petrol",
        "Diesel", "Diesel", "Petrol", "Petrol", "Diesel",
        "Petrol", "Diesel", "Diesel", "Petrol", "Diesel",
        "Petrol", "Petrol", "Petrol", "Diesel", "Petrol",
        "Petrol", "Petrol", "Diesel", "Petrol", "Petrol",
        "Diesel", "Petrol", "Diesel", "Diesel", "Petrol",
        "Petrol", "Diesel", "Petrol", "Petrol", "Diesel",
        "Diesel", "Petrol", "Petrol", "Diesel", "Petrol",
        "Diesel", "Petrol", "Diesel", "Petrol", "Petrol"],
"Transmission":[ "Automatic", "Manual", "Automatic", "Manual", "Manual",
        "Automatic", "Manual", "Manual", "Manual", "Automatic",
        "Automatic", "Automatic", "Manual", "Manual", "Automatic",
        "Automatic", "Manual", "Automatic", "Manual", "Manual",
        "Automatic", "Manual", "Automatic", "Automatic", "Manual",
        "Automatic", "Manual", "Automatic", "Automatic", "Manual",
        "Automatic", "Manual", "Manual", "Automatic", "Automatic",
        "Manual", "Manual", "Automatic", "Manual", "Automatic",
        "Automatic", "Manual", "Manual", "Automatic", "Manual",
        "Automatic", "Manual", "Automatic", "Manual", "Automatic"],
"Engine_cc":[  2500, 1800, 1500, 1200, 1500,
        1800, 1500, 1200, 1500, 1500,
        2000, 2800, 1500, 1200, 1500,
        1200, 2000, 2500, 1500, 1500,
        1600, 1200, 1500, 1800, 1500,
        1800, 1200, 1500, 2500, 1200,
        1500, 1500, 1500, 2000, 2800,
        1200, 1200, 1500, 1200, 2500,
        2000, 1500, 1600, 1800, 1200,
        2500, 1500, 1500, 1200, 1500],
"Owner_Count":[   1, 2, 1, 3, 1,
        2, 1, 2, 3, 1,
        2, 1, 2, 1, 2,
        1, 3, 2, 1, 2,
        1, 3, 2, 1, 2,
        1, 2, 1, 3, 2,
        1, 2, 3, 1, 2,
        1, 2, 1, 2, 3,
        1, 2, 1, 3, 2,
        1, 2, 3, 1, 2]}
df=pd.DataFrame(data)
df
# Out:
#     Car_ID    Brand      Model  Year  Price  Mileage Fuel_Type Transmission  \
# 0     1001   Toyota      Camry  2020  25000    45000    Petrol    Automatic
# 1     1002    Honda      Civic  2019  22000    52000    Diesel       Manual
# 2     1003  Hyundai      Creta  2021  24000    30000    Petrol    Automatic
# 3     1004   Maruti      Swift  2018  12000    60000    Petrol       Manual
# 4     1005     Tata      Nexon  2022  18000    25000    Diesel       Manual
# 5     1006   Toyota    Corolla  2020  27000    40000    Petrol    Automatic
# 6     1007    Honda       City  2019  21000    48000    Diesel       Manual
# 7     1008  Hyundai        i20  2021  16000    35000    Petrol       Manual
# 8     1009     Ford   EcoSport  2018  15000    70000    Diesel       Manual
# 9     1010      Kia     Seltos  2022  23000    28000    Petrol    Automatic
# 10    1011     Tata    Harrier  2020  28000    32000    Diesel    Automatic
# ...

# %%
#this line of code give number of rows and number of columns
df.shape
# Out:
# (50, 10)

# %%
# loc is used to find a particular row and column in a pandas dataframe
df.loc[2,"Price"]=np.nan
df.loc[9,"Price"]=np.nan
df.loc[19,"Mileage"]=np.nan
df.loc[29,"Mileage"]=np.nan
df.loc[39,"Fuel_Type"]=np.nan
df.loc[44,"Fuel_Type"]=np.nan

# %%
df.isnull().sum()
# Out:
# Car_ID          0
# Brand           0
# Model           0
# Year            0
# Price           2
# Mileage         2
# Fuel_Type       2
# Transmission    0
# Engine_cc       0
# Owner_Count     0
# dtype: int64

# %%
'''concat is use to sum to string syntax concat(a,b),
iloc is to select position using position index syntax
iloc[row index number,column index number]
ignore_index=True this tells pandas to forget the old
index number 5,10,20 and create a fresh index from 0'''
df=pd.concat([df,df.iloc[[5,10,20]]], ignore_index=True)

# %%
# adding inconsistent text vaues and numerical values in dataset
df.loc[0,'Brand']='toyota'
df.loc[1,'Brand']='TOYOTA'
df.loc[3,'Brand']='Toyta'

df.loc[4,'Fuel_Type']='petrol'
df.loc[7,'Fuel_Type']='PETROL'
df.loc[11,'Fuel_Type']='diesel'

df.loc[34,'Transmission']='automatic'
df.loc[27,'Transmission']='MANUAL'

df.loc[10,'Price']=-5000
df.loc[11,'Mileage']=-10000
df.loc[12,'Engine_cc']=-1500

# add invalid year values
df.loc[14,'Year']=1890
df.loc[15,'Year']=2035

# %%
''''to_csv() means:Save this DataFrame as a CSV file.
 "automotive_dataset_dirty.csv" this name we are giving to the file
 index=False Our DataFrame has an index:We don't need to save those
 index numbers as an extra column in our CSV.'''
df.to_csv('automotive_dataset_dirty.csv', index=False)
print("Dirty automotive dataset created successfully!")
# Out:
# Dirty automotive dataset created successfully!

# %%
df.shape
# Out:
# (53, 10)

# %%
print('Number of Rows : ',len(df))
print('Number of Columns : ',len(df.columns))
print('\nDuplicate values : ',df.duplicated().sum())
print('\nMissing values : ')
print(df.isnull().sum())
# Out:
# Number of Rows :  53
# Number of Columns :  10
#
# Duplicate values :  2
#
# Missing values :
# Car_ID          0
# Brand           0
# Model           0
# Year            0
# Price           2
# Mileage         2
# Fuel_Type       2
# Transmission    0
# Engine_cc       0
# Owner_Count     0
# dtype: int64

# %%
df=df.drop_duplicates()

# %%
df['Car_ID'].duplicated().sum()
# Out:
# np.int64(1)

# %%
df=df.drop_duplicates(subset='Car_ID')

# %%
df['Price']=df['Price'].fillna(df['Price'].median())
df['Mileage']=df['Mileage'].fillna(df['Mileage'].median())
df['Fuel_Type']=df['Fuel_Type'].fillna(df['Fuel_Type'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Car_ID          0
# Brand           0
# Model           0
# Year            0
# Price           0
# Mileage         0
# Fuel_Type       0
# Transmission    0
# Engine_cc       0
# Owner_Count     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#     Car_ID    Brand      Model  Year    Price  Mileage Fuel_Type Transmission  \
# 0     1001   toyota      Camry  2020  25000.0  45000.0    Petrol    Automatic
# 1     1002   TOYOTA      Civic  2019  22000.0  52000.0    Diesel       Manual
# 2     1003  Hyundai      Creta  2021  19500.0  30000.0    Petrol    Automatic
# 3     1004    Toyta      Swift  2018  12000.0  60000.0    Petrol       Manual
# 4     1005     Tata      Nexon  2022  18000.0  25000.0    petrol       Manual
# 5     1006   Toyota    Corolla  2020  27000.0  40000.0    Petrol    Automatic
# 6     1007    Honda       City  2019  21000.0  48000.0    Diesel       Manual
# 7     1008  Hyundai        i20  2021  16000.0  35000.0    PETROL       Manual
# 8     1009     Ford   EcoSport  2018  15000.0  70000.0    Diesel       Manual
# 9     1010      Kia     Seltos  2022  19500.0  28000.0    Petrol    Automatic
# 10    1011     Tata    Harrier  2020  -5000.0  32000.0    Diesel    Automatic
# ...

# %%
df[(df['Year']<2000) |(df['Year']>2026)]
# Out:
#     Car_ID    Brand  Model  Year    Price  Mileage Fuel_Type Transmission  \
# 14    1015  Hyundai  Venue  1890  19000.0  38000.0    Diesel    Automatic
# 15    1016      Kia  Sonet  2035  21000.0  29000.0    Petrol    Automatic
#
#     Engine_cc  Owner_Count
# 14       1500            2
# 15       1200            1

# %%
df.loc[(df['Year']<1900)|(df['Year']>2026),'Year']=np.nan

# %%
df['Year']=df['Year'].fillna(df['Year'].median())

# %%
df[df['Price']<0]
# Out:
#     Car_ID Brand    Model    Year   Price  Mileage Fuel_Type Transmission  \
# 10    1011  Tata  Harrier  2020.0 -5000.0  32000.0    Diesel    Automatic
#
#     Engine_cc  Owner_Count
# 10       2000            2

# %%
df.loc[df['Price']<0,'Price']=np.nan

# %%
df['Price']=df['Price'].fillna(df['Price'].median())

# %%
df[df['Mileage']<0]
# Out:
#     Car_ID   Brand     Model    Year    Price  Mileage Fuel_Type Transmission  \
# 11    1012  Toyota  Fortuner  2021.0  42000.0 -10000.0    diesel    Automatic
#
#     Engine_cc  Owner_Count
# 11       2800            1

# %%
df.loc[df['Mileage']<0,'Mileage']=np.nan

# %%
df['Mileage']=df['Mileage'].fillna(df['Mileage']).median()

# %%
df[df['Engine_cc']<0]
# Out:
#     Car_ID  Brand  Model    Year    Price  Mileage Fuel_Type Transmission  \
# 12    1013  Honda  Amaze  2019.0  17000.0  38500.0    Petrol       Manual
#
#     Engine_cc  Owner_Count
# 12      -1500            2

# %%
df.loc[df['Engine_cc']<0,'Engine_cc']=np.nan

# %%
df['Engine_cc'] = df['Engine_cc'].fillna(df['Engine_cc'].median())

# %%
df
# Out:
#     Car_ID    Brand      Model    Year    Price  Mileage Fuel_Type  \
# 0     1001   toyota      Camry  2020.0  25000.0  38500.0    Petrol
# 1     1002   TOYOTA      Civic  2019.0  22000.0  38500.0    Diesel
# 2     1003  Hyundai      Creta  2021.0  19500.0  38500.0    Petrol
# 3     1004    Toyta      Swift  2018.0  12000.0  38500.0    Petrol
# 4     1005     Tata      Nexon  2022.0  18000.0  38500.0    petrol
# 5     1006   Toyota    Corolla  2020.0  27000.0  38500.0    Petrol
# 6     1007    Honda       City  2019.0  21000.0  38500.0    Diesel
# 7     1008  Hyundai        i20  2021.0  16000.0  38500.0    PETROL
# 8     1009     Ford   EcoSport  2018.0  15000.0  38500.0    Diesel
# 9     1010      Kia     Seltos  2022.0  19500.0  38500.0    Petrol
# 10    1011     Tata    Harrier  2020.0  19500.0  38500.0    Diesel
# 11    1012   Toyota   Fortuner  2021.0  42000.0  38500.0    diesel
# 12    1013    Honda      Amaze  2019.0  17000.0  38500.0    Petrol
# ...

# %%
df["Brand"].unique()
# Out:
# array(['toyota', 'TOYOTA', 'Hyundai', 'Toyta', 'Tata', 'Toyota', 'Honda',
#        'Ford', 'Kia', 'Maruti'], dtype=object)

# %%
df['Brand']=df['Brand'].str.strip().str.title()

# %%
df['Brand']=df['Brand'].replace('Toyta','Toyota')

# %%
df['Model'].unique()
# Out:
# array(['Camry', 'Civic', 'Creta', 'Swift', 'Nexon', 'Corolla', 'City',
#        'i20', 'EcoSport', 'Seltos', 'Harrier', 'Fortuner', 'Amaze',
#        'Baleno', 'Venue', 'Sonet', 'Endeavour', 'Innova', 'Verna',
#        'Carens', 'Aspire', 'Punch'], dtype=object)

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'petrol', 'PETROL', 'diesel'], dtype=object)

# %%
df['Fuel_Type']=df['Fuel_Type'].str.strip().str.title()

# %%
df['Transmission'].unique()
# Out:
# array(['Automatic', 'Manual', 'MANUAL', 'automatic'], dtype=object)

# %%
df['Transmission'] = df['Transmission'].str.strip().str.title()

# %%
df.isnull().sum()
# Out:
# Car_ID          0
# Brand           0
# Model           0
# Year            0
# Price           0
# Mileage         0
# Fuel_Type       0
# Transmission    0
# Engine_cc       0
# Owner_Count     0
# dtype: int64

# %%
# Out:
#     Car_ID    Brand      Model    Year    Price  Mileage Fuel_Type  \
# 0     1001   Toyota      Camry  2020.0  25000.0  38500.0    Petrol
# 1     1002   Toyota      Civic  2019.0  22000.0  38500.0    Diesel
# 2     1003  Hyundai      Creta  2021.0  19500.0  38500.0    Petrol
# 3     1004   Toyota      Swift  2018.0  12000.0  38500.0    Petrol
# 4     1005     Tata      Nexon  2022.0  18000.0  38500.0    Petrol
# 5     1006   Toyota    Corolla  2020.0  27000.0  38500.0    Petrol
# 6     1007    Honda       City  2019.0  21000.0  38500.0    Diesel
# 7     1008  Hyundai        i20  2021.0  16000.0  38500.0    Petrol
# 8     1009     Ford   EcoSport  2018.0  15000.0  38500.0    Diesel
# 9     1010      Kia     Seltos  2022.0  19500.0  38500.0    Petrol
# 10    1011     Tata    Harrier  2020.0  19500.0  38500.0    Diesel
# 11    1012   Toyota   Fortuner  2021.0  42000.0  38500.0    Diesel
# 12    1013    Honda      Amaze  2019.0  17000.0  38500.0    Petrol
# ...
